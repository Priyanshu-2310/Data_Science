# %% [markdown]
# # Variables

# %%
x = 6
print(x)
print(type(x))
# Out:
# 6
# <class 'int'>

# %%
y = 5.6666
print(y)
print(type(y))
# Out:
# 5.6666
# <class 'float'>

# %%
z = 3 + 4j
print(z)
print(type(z))
# Out:
# (3+4j)
# <class 'complex'>

# %%
str = "hello sahil hu main"
print(str)
print(type(str))
# Out:
# hello sahil hu main
# <class 'str'>

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# str        str        hello sahil hu main
# x          int        6
# y          float      5.6666
# z          complex    (3+4j)

# %%
del z

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# str        str      hello sahil hu main
# x          int      6
# y          float    5.6666

# %% [markdown]
# # Multiple Assignemnet

# %%
a , b, c = 10, 12, 13
print(a, b, c)
# Out:
# 10 12 13
