# %% [markdown]
# # Operators

# %% [markdown]
# ## Arithmetic Operators

# %%
a = 11
b = 12
c= 11.2
d = 2 + 4j
e = 5 + 2j
f  = "hello"
g = "sahil"

# %%
# %whos
# Out:
# Variable   Type       Data/Info
# -------------------------------
# a          int        11
# b          int        12
# c          float      11.2
# d          str        hello
# e          complex    (5+2j)
# f          str        sahil

# %%
print(a + b)
# Out:
# 23

# %%
print(d + f)
# Out:
# hellosahil

# %% [markdown]
# ## Assignment Operator

# %%
num1 = 2
num2 = 3

# %%
num1+=num2
print(num1)
# Out:
# 5

# %%
num1-=num2
print(num1)
# Out:
# 2

# %%
num1*=num2
print(num1)
# Out:
# 18

# %%
num1/=num2
print(num1)
# Out:
# 6.0

# %% [markdown]
# ## Boolean Operator & Logical Operator

# %%
x = True
y = False
z = True

# %%
type(x)
# Out:
# bool

# %%
type(y)
# Out:
# bool

# %%
print(x and y)
# Out:
# False

# %%
print(x and z)
# Out:
# True

# %% [markdown]
# ### Or Operator

# %%
print(x or y)
# Out:
# True

# %%
print(x or z)
# Out:
# True

# %%
print((x and z ) or (x and y))
# Out:
# True

# %% [markdown]
# ### Not Operator

# %%
print(not (x))
# Out:
# False

# %%
print(not (y))
# Out:
# True

# %% [markdown]
# ### Comparison operator

# %%
new = 2 > 3
print(new)
# Out:
# False

# %%
type(new)
# Out:
# bool

# %%
new2 = 3 == 4
print(new2)
# Out:
# False

# %%
new3 = 3 == 3.0
print(new3)
# Out:
# True

# %%
p = 12
q = 8 
r = -3
s = 5.96

# %%
print((s > p) and (s > r))
# Out:
# False
