# %% [markdown]
# ## Unit 7

# %% [markdown]
# # String

# %%
s = "in data science python is very important to learn"
t = " and python is very easy to learn"
print(s + t)
# Out:
# in data science python is very important to learn and python is very easy to learn

# %%
a = "dog"
print(a*3)
# Out:
# dogdogdog

# %%
x = 45
print(type(x))
y = str(x)
type(y)
# Out:
# <class 'int'>
# str

# %% [markdown]
# ## Multiline String

# %%
m = """Python is my fav programming language 
i m learning python from basic to advanced
and i m putting my all efforts in it
"""

print(m)
# Out:
# Python is my fav programming language
# i m learning python from basic to advanced
# and i m putting my all efforts in it

# %%
print("""Its all about string
        a: does nothing
        b: does something
        c: does everything""")
# Out:
# Its all about string
#         a: does nothing
#         b: does something
#         c: does everything

# %% [markdown]
# ## Indexing and slicing in String

# %%
name = "Priyanshu"
print(name[-1])  # Last character
print(name[-2])  # Second last character
print(name[-5])
# Out:
# u
# h
# a

# %%
s = "why are you so worried about your exams ?"
print(s[0])
# Out:
# w

# %%
print(s[1])
# Out:
# h

# %%
print(len(s))
# Out:
# 41

# %%
print(s[40])
# Out:
# ?

# %%
print(s[0:3])
# Out:
# why

# %%
print(s[: : -1])
# Out:
# ? smaxe ruoy tuoba deirrow os uoy era yhw

# %% [markdown]
# ## Strip

# %%
a = "    priyans shu  "
b = a.strip()
print(b)
# Out:
# priyans shu

# %%
print(a)
# Out:
#     priyans shu

# %%
a = "*** Hello ***"
b = a.strip("*")
print(b)
# Out:
#  Hello

# %% [markdown]
# ## Lower Method

# %%
a = "Hello MMMMLLL"
b = a.lower()
print(b)
# Out:
# hello mmmmlll

# %% [markdown]
# ## Upper Methon

# %%
b = "hello kaise ho"
c = b.upper()
print(c)
# Out:
# HELLO KAISE HO

# %% [markdown]
# ## Replace Method

# %%
a = "hello how are you"
b = a.replace("hello", "hii")
print(b)
# Out:
# hii how are you

# %%
score = """math - 28 out of 30
           science - 32 out of 40
           hindi - 33 out of 44
           sst - 54 out of 100
        """
newscore = score.replace("out of", "/", 5)
print(newscore)
# Out:
# math - 28 / 30
#            science - 32 / 40
#            hindi - 33 / 44
#            sst - 54 / 100

# %% [markdown]
# ## Split Function

# %%
a = "this is python language"
print(a.split())
# Out:
# ['this', 'is', 'python', 'language']

# %%
print(a)
# Out:
# this is python language

# %%
list2 = a.split()

# %%
print(list2)
# Out:
# ['this', 'is', 'python', 'language']

# %%
newstr = "hello - hii - kaise ho - new"
b = print(newstr.split("-"))
print(b)
# Out:
# ['hello ', ' hii ', ' kaise ho ', ' new']
# None

# %%
c = "hello kaise ho mst hu m"
print(c.split(" ", 2))
# Out:
# ['hello', 'kaise', 'ho mst hu m']

# %% [markdown]
# ## Capitalize Method

# %%
a = "earth revolve around the sun"
print(a.capitalize())
# Out:
# Earth revolve around the sun

# %% [markdown]
# ## Title Method

# %%
a = "Earth revolve around the sun"
print(a.title())
# Out:
# Earth Revolve Around The Sun

# %%
b = "hellO kaisE hO"
print(b.title())
# Out:
# Hello Kaise Ho

# %% [markdown]
# ## SwapCase Method

# %%
str1 = "new delhi is the capital of india"
print(str1.swapcase())
# Out:
# NEW DELHI IS THE CAPITAL OF INDIA

# %% [markdown]
# ## Find Method

# %%
a = "python is great"
print(a.find("gre"))
# Out:
# 10

# %% [markdown]
# ## index Method

# %%
a = "hello hii kaise ho"
print(a.index("hii"))
# Out:
# 6

# %% [markdown]
# ## isalnum Method

# %%
a = "student"
print(a.isalnum())
# Out:
# True

# %%
a1 = "Student123"
print(a1.isalnum())
# Out:
# True

# %%
a2 = "Student 123"
print(a2.isalnum())
# Out:
# False

# %% [markdown]
# ## isalpha Methon

# %%
a = "hello"
print(a.isalpha())
# Out:
# True

# %%
a = "hello i m priyanshu verma"
print(a.isalpha())
# Out:
# False

# %% [markdown]
# ## isDigit Method

# %%
a = "7474747474"
print(a.isdigit())
# Out:
# True

# %%
b = "43433 34343"
print(b.isdigit())
# Out:
# False

# %%
"""take a number from user and check it is valid or not"""
a = input("Enter your mobile number")
if(a.isdigit()):
    print("Valid")
else:
    print("Invalid")
# Out:
# Enter your mobile number 121212121
# Valid

# %% [markdown]
# ## isUpper Method

# %%
str = "WELCOME TO THE PYTHON CLASS"
print(str.isupper())
# Out:
# True

# %%
str = "Welcome Hello"
print(str.isupper())
# Out:
# False

# %%
str = "Welcome hello"
print(str.isupper())
# Out:
# False

# %% [markdown]
# ## isLower Method

# %%
p = "hello how are you"
print(p.islower())
# Out:
# True

# %% [markdown]
# ## isTittle Method

# %%
p = "Python Is Ready"
print(p.istitle())
# Out:
# True

# %%
p1 = "Python is easy"
print(p1.istitle())
# Out:
# False

# %% [markdown]
# ## Startwith Method

# %%
a = "python is easy"
print(a.startswith("python"))
# Out:
# True

# %%
a = "python is easy"
print(a.startswith("is", 7))
# Out:
# True

# %% [markdown]
# ## Ends With

# %%
a = "python.py"
print(a.endswith(".py"))
# Out:
# True

# %%
a="python.py"
print(a.endswith("n.py"))
# Out:
# True

# %%
txt = "python.py"
print(txt.endswith(".txt"))
# Out:
# False

# %% [markdown]
# ## How to check a perticular substring is a part of string ??

# %%
a = "python is beautiful language"
print("beautiful" in a)
# Out:
# True
